# %% [markdown]
# # Import libs

# %%
import sys, os
if not sys.path[0] == os.path.abspath('..'):
    sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import numpy as np
from knn.knn import knn
from dmc.dmc import dmc
from bayes_classifier.bayes_classifier import bayes_classifier
from sklearn.model_selection import train_test_split
# from sklearn.metrics import confusion_matrix
from utils.functions import confusion_matrix, confusion_matrix_mean
from matplotlib import pyplot as plt

# %% [markdown]
# # Loading Iris dataset

# %%
Xy = pd.read_csv('./datasets/iris.csv')
X = Xy.drop(['class'], axis=1)
y = Xy['class']

# %% [markdown]
# # Running the tests and computing informations

# %%
realizations = 20
knn_hit_rate_list = []
dmc_hit_rate_list = []
b_hit_rate_list = []
knn_std_dev = 0
dmc_std_dev = 0
b_std_dev = 0
knn_confusion_matrix_list = []
dmc_confusion_matrix_list = []
b_confusion_matrix_list = []

for r in range(realizations):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

    knn_model = knn(k=3, type_distance_calc='euclidean')
    knn_model.fit(X_train, y_train)

    dmc_model = dmc(type_distance_calc='euclidean')
    dmc_model.fit(X_train, y_train)

    b_model = bayes_classifier()
    b_model.fit(X_train, y_train)

    knn_hit_rate_list.append(knn_model.score(X_test, y_test))
    dmc_hit_rate_list.append(dmc_model.score(X_test, y_test))
    b_hit_rate_list.append(b_model.score(X_test, y_test))

    knn_y_pred = [knn_model.predict(x) for x in X_test.values]
    dmc_y_pred = [dmc_model.predict(x) for x in X_test.values]
    b_y_pred = [b_model.predict(x) for x in X_test.values]

    knn_confusion_matrix_list.append(confusion_matrix(y_test, knn_y_pred))
    dmc_confusion_matrix_list.append(confusion_matrix(y_test, dmc_y_pred))
    b_confusion_matrix_list.append(confusion_matrix(y_test, b_y_pred))

knn_std_dev = np.std(knn_hit_rate_list)
dmc_std_dev = np.std(dmc_hit_rate_list)
b_std_dev = np.std(b_hit_rate_list)
# Out:
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])

# %% [markdown]
# # Showing knn informations computed

# %%
print('----------------- KNN model -----------------')
print('Hit rate:')
print(knn_hit_rate_list, end='\n\n')

print('Accuracy:')
print(sum(knn_hit_rate_list)/len(knn_hit_rate_list), end='\n\n')

print('Standard Deviation:')
print(knn_std_dev, end='\n\n')

print('Confusion Matrix:')
for matrix in knn_confusion_matrix_list:
    print(matrix, end='\n')
# Out:
# ----------------- KNN model -----------------
# Hit rate:
# [0.8666666666666667, 0.9666666666666667, 0.9, 0.9333333333333333, 0.9666666666666667, 0.9, 0.9666666666666667, 1.0, 0.9, 1.0, 0.9666666666666667, 0.9333333333333333, 1.0, 0.9666666666666667, 1.0, 0.9666666666666667, 0.9333333333333333, 0.9666666666666667, 0.9333333333333333, 0.9666666666666667]
#
# Accuracy:
# 0.9516666666666665
#
# Standard Deviation:
# 0.03723051317281445
#
# Confusion Matrix:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa               10                0               0
# Iris-versicolor            0               10               3
# Iris-virginica             0                1               6
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                1
# Iris-setosa                   0           10                0
# Iris-versicolor               0            0                8
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa                8                0               0
# Iris-versicolor            0                8               1
# Iris-virginica             0                2              11
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                7            0                1
# Iris-setosa                   0           11                0
# Iris-versicolor               1            0               10
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor                9               1            0
# Iris-virginica                 0               8            0
# Iris-setosa                    0               0           12
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa               10                0               0
# Iris-versicolor            0                7               2
# Iris-virginica             0                1              10
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica                7                0            0
# Iris-versicolor               1               12            0
# Iris-setosa                   0                0           10
#                  Iris-versicolor  Iris-setosa  Iris-virginica
# Iris-versicolor               13            0               0
# Iris-setosa                    0            7               0
# Iris-virginica                 0            0              10
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica               11                0            0
# Iris-versicolor               3                9            0
# Iris-setosa                   0                0            7
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                7            0                0
# Iris-setosa                   0           15                0
# Iris-versicolor               0            0                8
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               12            0                0
# Iris-setosa                   0            8                0
# Iris-versicolor               1            0                9
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                0
# Iris-setosa                   0            8                0
# Iris-versicolor               2            0                9
#                  Iris-versicolor  Iris-setosa  Iris-virginica
# Iris-versicolor               15            0               0
# Iris-setosa                    0            8               0
# Iris-virginica                 0            0               7
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor               10               1            0
# Iris-virginica                 0               9            0
# Iris-setosa                    0               0           10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                0
# Iris-setosa                   0            9                0
# Iris-versicolor               0            0               10
#                  Iris-setosa  Iris-virginica  Iris-versicolor
# Iris-setosa               12               0                0
# Iris-virginica             0               7                0
# Iris-versicolor            0               1               10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                6            0                2
# Iris-setosa                   0           14                0
# Iris-versicolor               0            0                8
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica               12                1            0
# Iris-versicolor               0                9            0
# Iris-setosa                   0                0            8
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor               10               2            0
# Iris-virginica                 0              12            0
# Iris-setosa                    0               0            6
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                7            0                0
# Iris-setosa                   0           10                0
# Iris-versicolor               1            0               12

# %%
confusion_matrix_mean(knn_confusion_matrix_list)
# Out:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa                9                0               0
# Iris-versicolor            0                9               1
# Iris-virginica             0                0               9

# %% [markdown]
# # Showing dmc informations computed

# %%
print('----------------- DMC model -----------------')
print('Hit rate:')
print(dmc_hit_rate_list, end='\n\n')

print('Accuracy:')
print(sum(dmc_hit_rate_list)/len(dmc_hit_rate_list), end='\n\n')

print('Standard Deviation:')
print(dmc_std_dev, end='\n\n')

print('Confusion Matrix:')
for matrix in dmc_confusion_matrix_list:
    print(matrix, end='\n')
# Out:
# ----------------- DMC model -----------------
# Hit rate:
# [0.8666666666666667, 0.7666666666666667, 0.9333333333333333, 0.9333333333333333, 0.8666666666666667, 0.8333333333333334, 0.9666666666666667, 0.9333333333333333, 0.9, 0.9333333333333333, 0.9333333333333333, 0.9, 0.9666666666666667, 0.9, 1.0, 0.9666666666666667, 0.8333333333333334, 0.9333333333333333, 0.9666666666666667, 0.8666666666666667]
#
# Accuracy:
# 0.9099999999999999
#
# Standard Deviation:
# 0.05587684871413402
#
# Confusion Matrix:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa               10                0               0
# Iris-versicolor            0               11               2
# Iris-virginica             0                2               5
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                6            0                6
# Iris-setosa                   0           10                0
# Iris-versicolor               1            0                7
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa                8                0               0
# Iris-versicolor            0                8               1
# Iris-virginica             0                1              12
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                7            0                1
# Iris-setosa                   0           11                0
# Iris-versicolor               1            0               10
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor                7               3            0
# Iris-virginica                 1               7            0
# Iris-setosa                    0               0           12
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa               10                0               0
# Iris-versicolor            0                6               3
# Iris-virginica             0                2               9
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica                7                0            0
# Iris-versicolor               1               12            0
# Iris-setosa                   0                0           10
#                  Iris-versicolor  Iris-setosa  Iris-virginica
# Iris-versicolor               12            0               1
# Iris-setosa                    0            7               0
# Iris-virginica                 1            0               9
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica                9                2            0
# Iris-versicolor               1               11            0
# Iris-setosa                   0                0            7
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                6            0                1
# Iris-setosa                   0           15                0
# Iris-versicolor               1            0                7
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                1
# Iris-setosa                   0            8                0
# Iris-versicolor               1            0                9
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                9            0                2
# Iris-setosa                   0            8                0
# Iris-versicolor               1            0               10
#                  Iris-versicolor  Iris-setosa  Iris-virginica
# Iris-versicolor               15            0               0
# Iris-setosa                    0            8               0
# Iris-virginica                 1            0               6
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor               10               1            0
# Iris-virginica                 2               7            0
# Iris-setosa                    0               0           10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                0
# Iris-setosa                   0            9                0
# Iris-versicolor               0            0               10
#                  Iris-setosa  Iris-virginica  Iris-versicolor
# Iris-setosa               12               0                0
# Iris-virginica             0               7                0
# Iris-versicolor            0               1               10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                5            0                3
# Iris-setosa                   0           14                0
# Iris-versicolor               2            0                6
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica               11                2            0
# Iris-versicolor               0                9            0
# Iris-setosa                   0                0            8
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor               12               0            0
# Iris-virginica                 1              11            0
# Iris-setosa                    0               0            6
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                5            0                2
# Iris-setosa                   0           10                0
# Iris-versicolor               2            0               11

# %%
confusion_matrix_mean(dmc_confusion_matrix_list)
# Out:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa                9                0               0
# Iris-versicolor            0                9               1
# Iris-virginica             0                1               8

# %% [markdown]
# # Showing bayes informations computed

# %%
print('----------------- BAYES model -----------------')
print('Hit rate:')
print(b_hit_rate_list, end='\n\n')

print('Accuracy:')
print(sum(b_hit_rate_list)/len(b_hit_rate_list), end='\n\n')

print('Standard Deviation:')
print(b_std_dev, end='\n\n')

print('Confusion Matrix:')
for matrix in b_confusion_matrix_list:
    print(matrix, end='\n')
# Out:
# ----------------- BAYES model -----------------
# Hit rate:
# [0.8666666666666667, 1.0, 0.9333333333333333, 0.9666666666666667, 0.9666666666666667, 0.9, 0.9666666666666667, 0.9666666666666667, 0.9, 1.0, 1.0, 0.9333333333333333, 0.9666666666666667, 0.9333333333333333, 1.0, 0.9666666666666667, 1.0, 0.9666666666666667, 0.9333333333333333, 0.9666666666666667]
#
# Accuracy:
# 0.9566666666666664
#
# Standard Deviation:
# 0.03666666666666666
#
# Confusion Matrix:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa               10                0               0
# Iris-versicolor            0                9               4
# Iris-virginica             0                0               7
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               12            0                0
# Iris-setosa                   0           10                0
# Iris-versicolor               0            0                8
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa                8                0               0
# Iris-versicolor            0                8               1
# Iris-virginica             0                1              12
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                8            0                0
# Iris-setosa                   0           11                0
# Iris-versicolor               1            0               10
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor                9               1            0
# Iris-virginica                 0               8            0
# Iris-setosa                    0               0           12
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa               10                0               0
# Iris-versicolor            0                6               3
# Iris-virginica             0                0              11
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica                7                0            0
# Iris-versicolor               1               12            0
# Iris-setosa                   0                0           10
#                  Iris-versicolor  Iris-setosa  Iris-virginica
# Iris-versicolor               12            0               1
# Iris-setosa                    0            7               0
# Iris-virginica                 0            0              10
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica               10                1            0
# Iris-versicolor               2               10            0
# Iris-setosa                   0                0            7
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                7            0                0
# Iris-setosa                   0           15                0
# Iris-versicolor               0            0                8
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               12            0                0
# Iris-setosa                   0            8                0
# Iris-versicolor               0            0               10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                0
# Iris-setosa                   0            8                0
# Iris-versicolor               2            0                9
#                  Iris-versicolor  Iris-setosa  Iris-virginica
# Iris-versicolor               14            0               1
# Iris-setosa                    0            8               0
# Iris-virginica                 0            0               7
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor                9               2            0
# Iris-virginica                 0               9            0
# Iris-setosa                    0               0           10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica               11            0                0
# Iris-setosa                   0            9                0
# Iris-versicolor               0            0               10
#                  Iris-setosa  Iris-virginica  Iris-versicolor
# Iris-setosa               12               0                0
# Iris-virginica             0               7                0
# Iris-versicolor            0               1               10
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                8            0                0
# Iris-setosa                   0           14                0
# Iris-versicolor               0            0                8
#                  Iris-virginica  Iris-versicolor  Iris-setosa
# Iris-virginica               12                1            0
# Iris-versicolor               0                9            0
# Iris-setosa                   0                0            8
#                  Iris-versicolor  Iris-virginica  Iris-setosa
# Iris-versicolor               10               2            0
# Iris-virginica                 0              12            0
# Iris-setosa                    0               0            6
#                  Iris-virginica  Iris-setosa  Iris-versicolor
# Iris-virginica                6            0                1
# Iris-setosa                   0           10                0
# Iris-versicolor               0            0               13

# %%
confusion_matrix_mean(b_confusion_matrix_list)
# Out:
#                  Iris-setosa  Iris-versicolor  Iris-virginica
# Iris-setosa                9                0               0
# Iris-versicolor            0                9               1
# Iris-virginica             0                0               9

# %% [markdown]
# # Choosing two columns from the last X_train and X_test to plot decision surface

# %%
X_train_2d, X_test_2d = X_train[['sepal-length', 'sepal-width']], X_test[['sepal-length', 'sepal-width']]

print('Train dataset:')
print(X_train_2d)
print('Test dataset:')
print(X_test_2d)
# Out:
# Train dataset:
#      sepal-length  sepal-width
# 147           6.5          3.0
# 120           6.9          3.2
# 83            6.0          2.7
# 8             4.4          2.9
# 7             5.0          3.4
# ..            ...          ...
# 27            5.2          3.5
# 119           6.0          2.2
# 146           6.3          2.5
# 41            4.5          2.3
# 68            6.2          2.2
#
# [120 rows x 2 columns]
# Test dataset:
#      sepal-length  sepal-width
# 130           7.4          2.8
# 116           6.5          3.0
# 31            5.4          3.4
# 39            5.1          3.4
# 50            7.0          3.2
# 131           7.9          3.8
# 145           6.7          3.0
# 89            5.5          2.5
# 13            4.3          3.0
# 56            6.3          3.3
# 59            5.2          2.7
# 51            6.4          3.2
# 93            5.0          2.3
# 63            6.1          2.9
# 3             4.6          3.1
# 19            5.1          3.8
# 45            4.8          3.0
# 74            6.4          2.9
# 5             5.4          3.9
# 90            5.5          2.6
# 94            5.6          2.7
# 53            5.5          2.3
# 126           6.2          2.8
# 133           6.3          2.8
# 46            5.1          3.8
# 72            6.3          2.5
# 121           5.6          2.8
# 23            5.1          3.3
# 76            6.8          2.8
# 17            5.1          3.5

# %% [markdown]
# # Training the models with the new dataset 2d

# %%
knn_model = knn(k=3, type_distance_calc='euclidean')
knn_model.fit(X_train_2d, y_train)
dmc_model = dmc(type_distance_calc='euclidean')
dmc_model.fit(X_train_2d, y_train)
b_model = bayes_classifier()
b_model.fit(X_train_2d, y_train)
# Out:
# w:\Home\ML\knn\knn.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.__y = pd.Series([])

# %% [markdown]
# # Plotting knn decision surface

# %%
data = X_test_2d[:][:].values

x_min, x_max = data[:, 0].min() - 0.1, data[:,0].max() + 0.1
y_min, y_max = data[:, 1].min() - 0.1, data[:, 1].max() + 0.1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 100),
np.linspace(y_min, y_max, 100))

x_in = np.c_[xx.ravel(), yy.ravel()]

y_pred = [[knn_model.predict(x) for x in x_in]]
for i, y in enumerate(y_pred[0]):
    if y == 'Iris-setosa':
        y_pred[0][i] = 1
    elif y == 'Iris-virginica':
        y_pred[0][i] = 2
    else:
        y_pred[0][i] = 3

y_pred = np.round(y_pred).reshape(xx.shape)

plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7 )

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

knn_y_pred = np.array([knn_model.predict(x) for x in X_test_2d.values])

setosa = np.where(knn_y_pred == 'Iris-setosa')
virginica = np.where(knn_y_pred == 'Iris-virginica')
versicolor = np.where(knn_y_pred == 'Iris-versicolor')

plt.scatter(data[setosa, 0], data[setosa, 1],
            color='red', marker='o', label='setosa')
plt.scatter(data[versicolor, 0], data[versicolor, 1],
            color='blue', marker='X', label='versicolor')
plt.scatter(data[virginica, 0], data[virginica, 1],
            color='yellow', marker='P', label='virginica')

plt.show()

# %% [markdown]
# # Plotting dmc decision surface

# %%
data = X_test_2d[:][:].values

x_min, x_max = data[:, 0].min() - 0.1, data[:,0].max() + 0.1
y_min, y_max = data[:, 1].min() - 0.1, data[:, 1].max() + 0.1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 100),
np.linspace(y_min, y_max, 100))

x_in = np.c_[xx.ravel(), yy.ravel()]

y_pred = [[dmc_model.predict(x) for x in x_in]]
for i, y in enumerate(y_pred[0]):
    if y == 'Iris-setosa':
        y_pred[0][i] = 1
    elif y == 'Iris-virginica':
        y_pred[0][i] = 2
    else:
        y_pred[0][i] = 3

y_pred = np.round(y_pred).reshape(xx.shape)

plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7 )

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

dmc_y_pred = np.array([dmc_model.predict(x) for x in X_test_2d.values])

setosa = np.where(dmc_y_pred == 'Iris-setosa')
virginica = np.where(dmc_y_pred == 'Iris-virginica')
versicolor = np.where(dmc_y_pred == 'Iris-versicolor')

plt.scatter(data[setosa, 0], data[setosa, 1],
            color='red', marker='o', label='setosa')
plt.scatter(data[versicolor, 0], data[versicolor, 1],
            color='blue', marker='X', label='versicolor')
plt.scatter(data[virginica, 0], data[virginica, 1],
            color='yellow', marker='P', label='virginica')

plt.show()

# %% [markdown]
# # Plotting bayes decision surface

# %%
data = X_test_2d[:][:].values

x_min, x_max = data[:, 0].min() - 0.1, data[:,0].max() + 0.1
y_min, y_max = data[:, 1].min() - 0.1, data[:, 1].max() + 0.1

xx, yy = np.meshgrid(np.linspace(x_min,x_max, 100),
np.linspace(y_min, y_max, 100))

x_in = np.c_[xx.ravel(), yy.ravel()]

y_pred = [[b_model.predict(x) for x in x_in]]
for i, y in enumerate(y_pred[0]):
    if y == 'Iris-setosa':
        y_pred[0][i] = 1
    elif y == 'Iris-virginica':
        y_pred[0][i] = 2
    elif y == 'Iris-versicolor':
        y_pred[0][i] = 3
    else:
        y_pred[0][i] = 4

y_pred = np.round(y_pred).reshape(xx.shape)

plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7 )

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

b_y_pred = np.array([b_model.predict(x) for x in X_test_2d.values])

setosa = np.where(b_y_pred == 'Iris-setosa')
virginica = np.where(b_y_pred == 'Iris-virginica')
versicolor = np.where(b_y_pred == 'Iris-versicolor')

plt.scatter(data[setosa, 0], data[setosa, 1],
            color='red', marker='o', label='setosa')
plt.scatter(data[versicolor, 0], data[versicolor, 1],
            color='blue', marker='X', label='versicolor')
plt.scatter(data[virginica, 0], data[virginica, 1],
            color='yellow', marker='P', label='virginica')

plt.show()
