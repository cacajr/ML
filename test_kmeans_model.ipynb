# %% [markdown]
# # Import Dataset

# %%
import pandas as pd


Xy = pd.read_csv('./datasets/iris.csv')
X = Xy.drop(['class'], axis = 1)
y = Xy['class']

# %% [markdown]
# # Separation in 80% train and 20% test

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# # Instantiating and training model

# %%
from kmeans.kmeans import kmeans


kmeans_model = kmeans(k=3, type_distance_calc='euclidean', number_iteration=300)
kmeans_model.fit(X_train)

# %%
kmeans_model.get_clusters()[0]
# Out:
#      sepal-length  sepal-width  petal-length  petal-width
# 3             6.5          3.0           5.2          2.0
# 11            6.9          3.1           5.4          2.1
# 21            6.7          3.0           5.0          1.7
# 22            6.7          3.1           5.6          2.4
# 25            6.1          2.6           5.6          1.4
# 31            6.3          2.9           5.6          1.8
# 32            6.9          3.1           5.1          2.3
# 34            6.3          3.3           6.0          2.5
# 35            6.4          2.8           5.6          2.2
# 36            7.2          3.6           6.1          2.5
# 39            6.3          3.4           5.6          2.4
# 45            7.7          2.8           6.7          2.0
# 47            6.7          3.3           5.7          2.1
# 49            6.8          3.2           5.9          2.3
# 52            6.7          3.3           5.7          2.5
# ...

# %%
kmeans_model.get_clusters()[1]
# Out:
#      sepal-length  sepal-width  petal-length  petal-width
# 2             5.9          3.0           5.1          1.8
# 4             5.5          2.3           4.0          1.3
# 5             6.2          2.9           4.3          1.3
# 8             6.8          2.8           4.8          1.4
# 9             6.3          2.7           4.9          1.8
# 10            5.1          2.5           3.0          1.1
# 12            6.7          3.1           4.4          1.4
# 14            6.1          3.0           4.6          1.4
# 15            5.6          2.7           4.2          1.3
# 16            5.7          3.0           4.2          1.2
# 17            5.7          2.8           4.5          1.3
# 24            5.9          3.2           4.8          1.8
# 30            6.3          3.3           4.7          1.6
# 37            6.3          2.8           5.1          1.5
# 38            5.8          2.7           3.9          1.2
# ...

# %%
kmeans_model.get_clusters()[2]
# Out:
#      sepal-length  sepal-width  petal-length  petal-width
# 0             5.4          3.4           1.5          0.4
# 1             5.4          3.4           1.7          0.2
# 6             5.4          3.9           1.7          0.4
# 7             5.1          3.8           1.9          0.4
# 13            4.8          3.1           1.6          0.2
# 18            4.8          3.0           1.4          0.3
# 19            5.1          3.7           1.5          0.4
# 20            5.0          3.4           1.5          0.2
# 23            4.3          3.0           1.1          0.1
# 26            4.4          3.2           1.3          0.2
# 27            5.0          3.3           1.4          0.2
# 28            5.1          3.5           1.4          0.3
# 29            5.0          3.5           1.3          0.3
# 33            4.6          3.2           1.4          0.2
# 42            5.0          3.2           1.2          0.2
# ...
